# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
temp = pd.read_csv("Temp_States.csv")
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Print `temp`.

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""

City: This column has the data type object, which typically represents strings or text data. In this case, it likely contains the names of different cities.

State: Similarly, the State column also has the data type object, indicating that it contains string data representing the names of states.

Temperature: The Temperature column has the data type float64, which indicates that it contains floating-point (decimal) numbers. In this case, it represents temperature values.

"""
# Out:
# '\n\nCity: This column has the data type object, which typically represents strings or text data. In this case, it likely contains the names of different cities.\n\nState: Similarly, the State column also has the data type object, indicating that it contains string data representing the names of states.\n\nTemperature: The Temperature column has the data type float64, which indicates that it contains floating-point (decimal) numbers. In this case, it represents temperature values.\n\n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
new_york = temp[temp['State'] == 'New York']
new_york
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
avg_temperature_ny = new_york['Temperature'].mean()
print ("The average of temperature of cities in New York : ", avg_temperature_ny)
# Out:
# The average of temperature of cities in New York :  10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
cities_state_above_15 = temp[temp['Temperature'] > 15]
cities_state_above_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
cities_above_15 = temp[temp['Temperature'] > 15][['City','Temperature']]
cities_above_15
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
cities_15_20 = (temp['Temperature'] > 15) & (temp['Temperature'] < 20)
cities_between_15_and_20 = temp[cities_15_20][['City', 'Temperature']]
cities_between_15_and_20
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
state_stats = temp.groupby('State')['Temperature'].agg(['mean', 'std'])
state_stats
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
employees = pd.read_csv("Employee.csv")
employees
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
employees.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
The columns of Name, Department, Education, Gender and Title has the data type object, which typically represents strings or text data. 
The column Years and Salary has the data type float64, which indicates that it contains floating-point (decimal) numbers.
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
avg_salary = employees['Salary'].mean()
print("The average salary in this company is ", avg_salary)
# Out:
# The average salary in this company is  48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
max_salary = employees['Salary'].max()
print("The highest salary in this company is ", max_salary)
# Out:
# The highest salary in this company is  70

# %% [markdown]
# #### What's the lowest salary?

# %%
min_salary = employees['Salary'].min()
print("The lowest salary in this company is ", min_salary)
# Out:
# The lowest salary in this company is  30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employees_low = employees[employees['Salary'] == min_salary]
employees_low
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
david_info = employees[employees['Name'] == 'David']
david_info
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
david_salary = employees[employees['Name'] == 'David']['Salary']
david_salary
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
job_associate = employees[employees['Title'] == 'associate']
job_associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
employees.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
employees[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
associate_salary = employees[(employees['Title'] == 'associate') & (employees['Salary'] > 55)]
associate_salary
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
n_years = employees.groupby('Years')['Salary'].mean()
n_years
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average salary per title?

# %%
avg_title = employees.groupby('Title')['Salary'].mean()
avg_title
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# ####  Find the salary quartiles.

# %%
avg_title.describe()
# Out:
# count     3.000000
# mean     53.055556
# std      19.009013
# min      32.500000
# 25%      44.583333
# 50%      56.666667
# 75%      63.333333
# max      70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
gender = employees.groupby('Gender')['Salary'].mean()
gender

#yes
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
employees.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
department_stats = employees.groupby('Department').agg({'Years': ['min', 'mean', 'max'],
                                                 'Salary': ['min', 'mean', 'max']})
department_stats
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
salary_difference = lambda x: x.max() - x.min()

department_salary_difference = employees.groupby('Department')['Salary'].agg(salary_difference)
department_salary_difference
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
orders = pd.read_csv("Orders.csv")
orders.head(3)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
# 2      cream cupid hearts coat hanger         8  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
"""

This dataset ontains various columns with different data types: int64, object and float64
InvoiceDate: String (object) - This should ideally be in datetime format.

"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
avg_price = orders['UnitPrice'].mean()
print("The average purchase price is ",avg_price )
# Out:
# The average purchase price is  3.1161744805540756

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
highest_price = orders['UnitPrice'].max()
lowest_price = orders['UnitPrice'].min()

print("Highest Purchase Price:", highest_price)
print("Lowest Purchase Price:", lowest_price)
# Out:
# Highest Purchase Price: 8142.75
# Lowest Purchase Price: 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
customers_spain = orders[orders['Country'] == 'Spain'][['CustomerID', 'Country']]
customers_spain
# Out:
#         CustomerID Country
# 4250         12557   Spain
# 4251         12557   Spain
# 4252         12557   Spain
# 4253         12557   Spain
# 4254         12557   Spain
# ...            ...     ...
# 394733       17097   Spain
# 394734       17097   Spain
# 394735       17097   Spain
# 394736       17097   Spain
# 394737       17097   Spain
#
# [2485 rows x 2 columns]

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
num_customers_spain = orders[orders['Country'] == 'Spain']['CustomerID'].nunique()

print("Number of customers in Spain:", num_customers_spain)
# Out:
# Number of customers in Spain: 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# customer_total_quantity = orders.groupby('CustomerID')['Quantity'].sum()
# customers_more_than_50_items = customer_total_quantity[customer_total_quantity > 50]
# customers_more_than_50_items

customers_more_than_50_items = orders.groupby('CustomerID')['Quantity'].sum()[lambda x: x > 50]
customers_more_than_50_items
# Out:
# CustomerID
# 12346    74215
# 12347     2458
# 12348     2341
# 12349      631
# 12350      197
#          ...
# 18278       66
# 18281       54
# 18282      103
# 18283     1397
# 18287     1586
# Name: Quantity, Length: 4091, dtype: int64

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
orders_spain_more_than_50_items = orders[(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]
orders_spain_more_than_50_items
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
orders_free = orders[(orders['amount_spent'] == 0)]
orders_free
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
orders_lunch_bag = orders[orders['Description'].str.startswith('lunch bag')]
orders_lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
lunch_bag_orders_2011 = orders[(orders['Description'].str.startswith('lunch bag')) & (orders['year'] == 2011)]
lunch_bag_orders_2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
amount_spent_distribution = orders[orders['Country'] == 'Spain']['amount_spent'].value_counts()
amount_spent_distribution
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
#          ...
# 3.36        1
# 8.67        1
# 5.85        1
# 27.00       1
# 109.50      1
# Name: amount_spent, Length: 316, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
orders_august = orders[orders['month'] == 8]
orders_august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
order_count_by_country = orders_august['Country'].value_counts()
order_count_by_country
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
average_amount_by_country = orders.groupby('Country')['amount_spent'].mean()
average_amount_by_country
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
most_expensive_item = orders[orders['UnitPrice'] == orders['UnitPrice'].max()]
most_expensive_item
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
average_amount_per_year = orders.groupby('year')['amount_spent'].mean()
average_amount_per_year
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
